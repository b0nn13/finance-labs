# %% [markdown]
# <a href="https://colab.research.google.com/github/b0nn13/finance-labs/blob/master/GetFinanceData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define the ticker list
# !pip install pandas
# !pip install yfinance
# !pip install matplotlib

import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tickers_list = ['WEGE3.SA', 'EGIE3.SA']
#tickers_list = ['ITSA3.SA', 'ITSA4.SA', 'LREN3.SA', 'PETR4.SA', 'MGLU3.SA', 'NATU3.SA']
# Import pandas
data = pd.DataFrame(columns=tickers_list)

# %%
# Fetch the data
for ticker in tickers_list:
 dataSource = yf.download(ticker,period="max")['Adj Close']
 #data[ticker] = dataSource['Adj Close']
 # Print first 5 rows of the data
 dataSource.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(15, 7))
# Show the legend
plt.legend()
# Define the label for the title of the figure
plt.title('Preço de Fechamento Ajustado', fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Preço', fontsize=14)
plt.xlabel('Ano', fontsize=14)
# Plot the grid lines
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()
