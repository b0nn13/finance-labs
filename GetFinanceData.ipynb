# %% [markdown]
# <a href="https://colab.research.google.com/github/b0nn13/finance-labs/blob/master/GetFinanceData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importanodo pacotes necessários
# !pip install pandas
# !pip install yfinance
# !pip install matplotlib

import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import date

# %%
# Definindo empresas a serem consultadas
tickers_list = ['CNTO3.SA', 'ITSA3.SA', 'KNCR11.SA', 'KNRI11.SA', 'LREN3.SA', 'MGLU3.SA', 'WEGE3.SA']
#Definindo DataFrame
data = pd.DataFrame(columns=tickers_list)
print(data)
# Out:
# Empty DataFrame
# Columns: [CNTO3.SA, ITSA3.SA, KNCR11.SA, KNRI11.SA, LREN3.SA, MGLU3.SA, WEGE3.SA]
# Index: []

# %%
# Percorre cada ticker a ser consultado
for ticker in tickers_list:
 # consulta dados on yahoo finance e armazena na coluna com o nome do ticker
 data[ticker] = yf.download(ticker,start="2020-01-01", end=str(date.today()))['Adj Close']
 # Print first 5 rows of the data
data.dropna()  
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              CNTO3.SA   ITSA3.SA   KNCR11.SA  ...   LREN3.SA   MGLU3.SA   WEGE3.SA
# Date                                          ...
# 2020-01-02  37.430000  13.984178  106.000000  ...  57.500000  49.330002  35.240002
# 2020-01-03  37.970001  14.013700  106.500000  ...  57.099998  48.889999  34.790001
# 2020-01-06  38.000000  13.875926  106.830002  ...  57.049999  48.930000  34.880001
# 2020-01-07  38.650002  13.738151  106.980003  ...  57.020000  48.790001  35.150002
# ...

# %%
# Calcula variação acumulada
dataVar = ((data.pct_change()+1).cumprod())
#dataVar = dataVar.fillna(0)

# plota(cria) o gráfico
dataVar.plot(figsize=(15, 7))
#Exibe a legenda 
plt.legend()
# Define label para o título do gráfico
plt.title('Variação do Preço Ajustado', fontsize=16)
# Define label para os eixos x e y
plt.ylabel('Preço', fontsize=14)
plt.xlabel('Ano', fontsize=14)
# Estitilização de linhas
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
# Exibe o gráfico
plt.show()

# %%
dete = ((data.pct_change()+1).cumprod())
dete = dete.fillna(0)
print(dete)
# Out:
#             KNCR11.SA  WEGE3.SA  ITSA3.SA  KNRI11.SA  LREN3.SA  WEGE3.SA
# Date
# 2019-10-17   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# 2019-10-18   1.003814  1.004951  0.977239   0.994048  0.990921  1.004951
# 2019-10-21   1.004890  1.008251  0.989721   1.002857  1.006181  1.008251
# 2019-10-22   1.007237  1.020627  1.009545   1.008929  1.002704  1.020627
# 2019-10-23   1.004205  1.066007  1.013216   1.005952  0.986865  1.066007
# 2019-10-24   1.001956  1.076733  1.007342   1.019048  0.951709  1.076733
# 2019-10-25   1.006161  1.048267  1.020558   1.017679  0.975468  1.048267
# 2019-10-28   1.000685  1.055281  1.024229   1.027976  0.966776  1.055281
# 2019-10-29   1.000880  1.052805  1.017621   1.020893  0.969867  1.052805
# 2019-10-30   1.009095  1.066419  1.027166   1.015833  0.971219  1.066419
# 2019-10-31   1.021418  1.051980  1.013216   1.011905  0.980297  1.051980
# 2019-11-01   1.006357  1.067657  1.013216   1.014881  0.998068  1.067657
# ...
